# %% [markdown]
# # **Dağılım Ölçütleri: Standart Sapma**🟢
# **Standart sapma**, bir veri setindeki değerlerin ortalama değere ne kadar yayıldığını ölçen bir istatistiksel ölçüdür. Yani, standart sapma, veri noktalarının ortalama değerden ne kadar uzak olduğunu gösterir ve veri setinin dağılımını ifade eder. Daha yüksek bir standart sapma, veri noktalarının ortalama değere daha fazla yayıldığını gösterirken, daha düşük bir standart sapma, veri noktalarının ortalama değere daha yakın olduğunu gösterir.
#
# **Popülasyon Standart Sapması Formülü:
# Popülasyon standart sapması, bir veri setindeki "N" adet değerin ortalama değerinden ne kadar uzak olduğunun ölçüsüdür. Popülasyon standart sapması "σ" ile gösterilir ve aşağıdaki formülle hesaplanır:
#
# ![popü.PNG](data:image/png;base64,...)
#
# **Örnekleme Göre Standart Sapma Formülü:**
# Örnekleme göre standart sapma, bir veri setinden alınan örneklemin ortalama değerinden ne kadar uzak olduğunun ölçüsüdür. Örnekleme göre standart sapma "s" ile gösterilir ve Bessel düzeltmesi uygulanarak aşağıdaki formülle hesaplanır:
#
# ![örne.PNG](data:image/png;base64,...)
#
# Bu formüller, bir veri setinin standart sapmasını popülasyon ve örnekleme göre hesaplamanın temelini oluşturur.

# %%
import numpy as np

# Rastgele veri seti oluşturma
np.random.seed(0)  # Çalışmanın tekrarlanabilir olması için random seed ayarlanıyor
veri_seti = np.random.randint(0, 100, 100)  # 0 ile 100 arasında rastgele 100 sayıdan oluşan bir veri seti


# Popülasyon standart sapması hesaplama
populasyon_std = np.std(veri_seti)

# Örnekleme göre standart sapma hesaplama
ornekleme_std = np.std(veri_seti, ddof=1)  # ddof=1, Bessel düzeltmesini sağlar

print("Popülasyon Standart Sapması:", populasyon_std)
print("Örnekleme Göre Standart Sapma:", ornekleme_std)
# Out:
# Popülasyon Standart Sapması: 28.230074388849918
# Örnekleme Göre Standart Sapma: 28.37229228837476

# %% [markdown]
# # **Dağılım Ölçütleri: Varyans**🟢
# **Varyans**, bir veri setindeki değerlerin ortalama değere ne kadar yayıldığını ölçen bir istatistiksel ölçüdür. Yani, varyans, veri noktalarının ortalama değerden ne kadar uzak olduğunu gösterir ve veri setinin dağılımını ifade eder. Daha yüksek bir varyans, veri noktalarının ortalama değere daha fazla yayıldığını gösterirken, daha düşük bir varyans, veri noktalarının ortalama değere daha yakın olduğunu gösterir.
#
# **Popülasyon Varyansı Formülü:**
# Popülasyon varyansı, bir veri setindeki "N" adet değerin ortalama değere ne kadar uzak olduğunun karelerinin ortalamasıdır. Popülasyon varyansı "σ^2" ile gösterilir ve aşağıdaki formülle hesaplanır:
#
# ![var popü.PNG](data:image/png;base64,...)
#
# **Örnekleme Göre Varyans Formülü:**
# Örnekleme göre varyans, bir veri setinden alınan örneklemin ortalama değerinden ne kadar uzak olduğunun karelerinin ortalamasıdır. Örnekleme göre varyans "s^2" ile gösterilir ve Bessel düzeltmesi uygulanarak aşağıdaki formülle hesaplanır:
#
# ![var örne.PNG](data:image/png;base64,...)
#
# Bu formüller, bir veri setinin varyansını popülasyon ve örnekleme göre hesaplamanın temelini oluşturur.

# %%
import numpy as np

# Örnek veri seti
veri_seti = [5, 8, 10, 12, 6, 9, 11, 14, 7]

# Popülasyon varyansı hesaplama
populasyon_varyansi = np.var(veri_seti)

# Örnekleme göre varyans hesaplama
ornekleme_varyansi = np.var(veri_seti, ddof=1)  # ddof=1, Bessel düzeltmesini sağlar

print("Popülasyon Varyansı:", populasyon_varyansi)
print("Örnekleme Göre Varyans:", ornekleme_varyansi)
# Out:
# Popülasyon Varyansı: 7.65432098765432
# Örnekleme Göre Varyans: 8.61111111111111

# %% [markdown]
# # **Dağılım Ölçütleri: Skewness (Çarpıklık)**🟢
#
# Skewness (Çarpıklık), bir olasılık dağılımının veya veri setinin simetrisizliğini ölçen bir istatistiksel terimdir. Bir dağılımın çarpıklığı, dağılımın merkezi eğilimine (ortalama, medyan, mod gibi) göre nasıl eğildiğini gösterir.
#
# Bir veri setinin çarpıklığı üç farklı şekilde olabilir:
#
# **1.Negatif Çarpıklık (Negative Skewness):** Bir veri seti negatif çarpıksa, bu, veri setinin sola doğru çarpık olduğunu gösterir. Yani, veri seti genellikle sağ kuyruğu uzun olan ve sola doğru uzanan bir dağılım sergiler. Medyan, ortalama değerden daha küçük olacaktır.
#
# **2.Pozitif Çarpıklık (Positive Skewness):** Bir veri seti pozitif çarpıksa, bu, veri setinin sağa doğru çarpık olduğunu gösterir. Yani, veri seti genellikle sol kuyruğu uzun olan ve sağa doğru uzanan bir dağılım sergiler. Medyan, ortalama değerden daha büyük olacaktır.
#
# **3.Sıfır Çarpıklık (Zero Skewness):** Bir veri seti sıfır çarpıksa, bu, veri setinin simetrik olduğunu ve sağa veya sola doğru bir eğilimin olmadığını gösterir. Bu durumda, veri setinin medyanı, ortalama değere eşit olacaktır.
#
# Çarpıklık, veri setinin dağılımının görselleştirilmesi ve anlaşılması için önemlidir. Özellikle, veri setinin simetrik olup olmadığını ve merkezi eğilim ölçüleriyle (örneğin, ortalama ve medyan) nasıl ilişkili olduğunu belirlemek için kullanılır. Bir veri setinin çarpıklığını anlamak, veri setinin doğru analiz edilmesi ve yorumlanması için önemlidir.
#
# ![Skewness_1.webp](data:image/webp;base64,...)

# %% [markdown]
# **Örnek 1:**
# Bu kod örneğinde, öncelikle NumPy kütüphanesini kullanarak bir normal dağılıma sahip 1000 elemanlı bir örnek veri seti oluşturuyoruz. Daha sonra, oluşturduğumuz bu veri setinin histogramını çiziyoruz. Histogramı çizerken, plt.hist() fonksiyonunu kullanarak veri setini, istenen bin sayısı ve diğer grafik ayarlarını belirtiyoruz.
#
# Ardından, scipy.stats.skew() fonksiyonunu kullanarak veri setinin çarpıklığını hesaplıyoruz. Elde ettiğimiz çarpıklık değerini, histogram grafiğinin üzerine yazdırıyoruz.
#
# Son olarak, çizilen grafik ve hesaplanan çarpıklık değeri ile birlikte bir grafik oluşturuyoruz. Bu şekilde, veri setinin dağılımını görselleştiriyoruz ve çarpıklık hakkında bilgi elde ediyoruz.

# %%
#Örnek 1
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew

# Örnek veri seti oluşturma
np.random.seed(0)
veri_seti = np.random.normal(loc=10, scale=5, size=1000)  # Ortalaması 10, standart sapması 5 olan 1000 elemanlı normal dağılım

# Veri setinin histogramını çizme
plt.hist(veri_seti, bins=30, density=True, alpha=0.6, color='g')

# Veri setinin çarpıklığını hesaplama
veri_seti_carpiklik = skew(veri_seti)

# Çarpıklık değerini ekrana yazdırma
plt.text(30, 0.05, f"Çarpıklık: {veri_seti_carpiklik:.2f}", fontsize=15)

# Grafik ayarları
plt.xlabel('Değerler')
plt.ylabel('Yoğunluk')
plt.title('Veri Seti Histogramı ve Çarpıklık')
plt.grid(True)
plt.show()

# %% [markdown]
# **Örnek 2:**
# Bu kodda, önce farklı dağılımlara sahip üç örnek veri seti oluşturuyoruz: normal, gamma ve log-normal dağılımları. Daha sonra, her bir veri setinin çarpıklığını hesaplayıp, her biri için histogramlarını çizdiriyoruz. Her histogramın başlığında, hesaplanan çarpıklık değeri yer alıyor. Bu şekilde, farklı dağılımlara sahip veri setlerinin çarpıklıklarını görselleştirip, karşılaştırma yapabiliyoruz.

# %%
#Örnek 2
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew, gamma, lognorm

# Örnek veri seti oluşturma
np.random.seed(0)
veri_seti_normal = np.random.normal(loc=0, scale=1, size=1000)  # Normal dağılım
veri_seti_gamma = gamma.rvs(a=2, size=1000)  # Gamma dağılımı
veri_seti_lognorm = lognorm.rvs(s=0.5, size=1000)  # Log-normal dağılımı

# Veri setlerinin çarpıklığını hesaplama
normal_carpiklik = skew(veri_seti_normal)
gamma_carpiklik = skew(veri_seti_gamma)
lognorm_carpiklik = skew(veri_seti_lognorm)

# Histogramları çizdirme
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.hist(veri_seti_normal, bins=30, density=True, alpha=0.6, color='g')
plt.title(f'Normal Dağılım\nÇarpıklık: {normal_carpiklik:.2f}')

plt.subplot(1, 3, 2)
plt.hist(veri_seti_gamma, bins=30, density=True, alpha=0.6, color='b')
plt.title(f'Gamma Dağılımı\nÇarpıklık: {gamma_carpiklik:.2f}')

plt.subplot(1, 3, 3)
plt.hist(veri_seti_lognorm, bins=30, density=True, alpha=0.6, color='r')
plt.title(f'Log-Normal Dağılımı\nÇarpıklık: {lognorm_carpiklik:.2f}')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Dağılım Ölçütleri: Kurtosis (Basıklık)**🟢
#
# **Kurtosis**, bir olasılık dağılımının veya veri setinin sivriği veya düzleği hakkında bilgi veren bir istatistiksel terimdir. Yani, bir dağılımın kurtosis değeri, dağılımın zirvesinin (tepe noktasının) ne kadar sivri veya düz olduğunu ölçer. Kurtosis, dağılımın uç değerlerinin yoğunlaşmasını inceler.
#
# Kurtosis değeri, genellikle dört farklı türde tanımlanır:
#
# **1. Mesokurtik (Mesokurtic):** Normal dağılıma (standart normal dağılıma) benzer bir kurtosis yapısına sahip dağılımlar mesokurtik olarak adlandırılır. Mesokurtik bir dağılım, ortalama kurtosis değeri olan 0'a sahiptir.
#
# **2. Leptokurtik (Leptokurtic):** Leptokurtik bir dağılım, normal dağılıma göre daha sivri ve daha az yayılmıştır. Uç değerlerin normal dağılıma göre daha yoğun olduğu durumlarda leptokurtik bir kurtosis değeri elde edilir. Leptokurtik bir dağılım, kurtosis değeri pozitif olan bir dağılımdır.
#
# **3. Platykurtik (Platykurtic):** Platykurtik bir dağılım, normal dağılıma göre daha düz ve daha geniş bir yayılıma sahiptir. Uç değerlerin normal dağılıma göre daha az yoğun olduğu durumlarda platykurtik bir kurtosis değeri elde edilir. Platykurtik bir dağılım, kurtosis değeri negatif olan bir dağılımdır.
#
#
# *Özetle, kurtosis değeri, bir veri setinin dağılımının sivriği veya düzleği hakkında bilgi sağlar. Mesokurtik dağılımlar genellikle simetrik ve normal dağılıma benzerken, leptokurtik ve platykurtik dağılımlar daha farklı özelliklere sahiptir.*
#
# ![3-s2.0-B9780128168189000159-f05-02-9780128168189.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Bu programda, farklı dağılımlara sahip üç örnek veri setinin kurtosis değerlerini hesaplayacağız ve bunları karşılaştırmak için bir grafik oluşturacağız. İşte bu program için bir Python kodu:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import kurtosis, gamma, lognorm

# Örnek veri setlerini oluşturma
np.random.seed(0)
normal_data = np.random.normal(loc=0, scale=1, size=1000)  # Normal dağılım
gamma_data = gamma.rvs(a=2, size=1000)  # Gamma dağılımı
lognorm_data = lognorm.rvs(s=0.5, size=1000)  # Log-normal dağılımı

# Veri setlerinin kurtosis değerlerini hesaplama
kurtosis_normal = kurtosis(normal_data)
kurtosis_gamma = kurtosis(gamma_data)
kurtosis_lognorm = kurtosis(lognorm_data)

# Histogramları çizdirme
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.hist(normal_data, bins=30, density=True, alpha=0.6, color='g')
plt.title(f'Normal Dağılım\nKurtosis: {kurtosis_normal:.2f}')

plt.subplot(1, 3, 2)
plt.hist(gamma_data, bins=30, density=True, alpha=0.6, color='b')
plt.title(f'Gamma Dağılımı\nKurtosis: {kurtosis_gamma:.2f}')

plt.subplot(1, 3, 3)
plt.hist(lognorm_data, bins=30, density=True, alpha=0.6, color='r')
plt.title(f'Log-Normal Dağılımı\nKurtosis: {kurtosis_lognorm:.2f}')

plt.tight_layout()
plt.show()

# %% [markdown]
# Bu kod, normal, gamma ve log-normal dağılımları için örnek veri setleri oluşturur. Daha sonra, her bir veri setinin kurtosis değerini hesaplar ve bu değerleri histogramların başlıklarında gösterir. Sonuç olarak, üç farklı dağılımın kurtosis değerlerini karşılaştıran bir grafik elde ederiz.
